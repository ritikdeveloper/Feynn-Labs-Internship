# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
from sklearn import preprocessing
from bioinfokit.visuz import cluster
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from collections import Counter
from statsmodels.graphics.mosaicplot import mosaic
from itertools import product

# %%
dataset = pd.read_csv("Dataset 2/ev-charging-stations-india.csv")

# %%
dataset.shape
# Out:
# (1547, 7)

# %%
dataset.head()
# Out:
#                                                 name          state      city  \
# 0                 Neelkanth Star DC Charging Station        Haryana  Gurugram
# 1                       Galleria DC Charging Station        Haryana  Gurugram
# 2  Highway Xpress (Jaipur-Delhi) DC charging station      Rajasthan    Behror
# 3                  Food Carnival DC Charging Station  Uttar Pradesh  Khatauli
# 4                  Food Carnival AC Charging Station  Uttar Pradesh  Khatauli
#
#                                              address lattitude  longitude  \
# 0  Neelkanth Star Karnal, NH 44, Gharunda, Kutail...   29.6019    76.9803
# 1  DLF Phase IV, Sector 28, Gurugram, Haryana 122022   28.4673    77.0818
# 2  Jaipur to Delhi Road, Behror Midway, Behror, R...   27.8751    76.2760
# 3  Fun and Food Carnival, NH 58, Khatauli Bypass,...   29.3105    77.7218
# 4  NH 58, Khatauli Bypass, Bhainsi, Uttar Pradesh...   29.3105    77.7218
#
#    type
# 0  12.0
# 1  12.0
# 2  12.0
# 3  12.0
# 4  12.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1547 entries, 0 to 1546
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       1547 non-null   object
#  1   state      1547 non-null   object
#  2   city       1547 non-null   object
#  3   address    1507 non-null   object
#  4   lattitude  1541 non-null   object
#  5   longitude  1541 non-null   float64
#  6   type       1539 non-null   float64
# dtypes: float64(2), object(5)
# memory usage: 84.7+ KB

# %%
dataset.isnull().sum()
# Out:
# name          0
# state         0
# city          0
# address      40
# lattitude     6
# longitude     6
# type          8
# dtype: int64

# %%
dataset = dataset.drop(columns=["address"])

# %%
dataset.dropna(axis=0, inplace=True)

# %%
dataset.isnull().sum()
# Out:
# name         0
# state        0
# city         0
# lattitude    0
# longitude    0
# type         0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1533 entries, 0 to 1546
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       1533 non-null   object
#  1   state      1533 non-null   object
#  2   city       1533 non-null   object
#  3   lattitude  1533 non-null   object
#  4   longitude  1533 non-null   float64
#  5   type       1533 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 83.8+ KB

# %%
entries_by_region= dataset['state'].value_counts()

# %%
plt.figure(figsize=(10, 6))
entries_by_region.plot(kind='bar')
plt.xlabel('State')
plt.ylabel('Number of Entries')
plt.title('Entries by State')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(entries_by_power, labels=entries_by_power.index, autopct='%1.1f%%', startangle=140)
plt.title('Entries by State')
plt.axis('equal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5568\2825155196.py in <module>
#       1 plt.figure(figsize=(8, 8))
# ----> 2 plt.pie(entries_by_power, labels=entries_by_power.index, autopct='%1.1f%%', startangle=140)
#       3 plt.title('Entries by State')
#       4 plt.axis('equal')
#
# NameError: name 'entries_by_power' is not defined

# %%
entries_by_power= dataset['power'].value_counts()

# %%
plt.figure(figsize=(8, 8))
plt.pie(entries_by_region, labels=entries_by_region.index, autopct='%1.1f%%', startangle=140)
plt.title('Entries by Power')
plt.axis('equal')
# Out:
# (-1.0999981373237577,
#  1.0999999096308535,
#  -1.099999990357654,
#  1.0999999995402763)

# %%
entries_by_type=dataset['type'].value_counts()

# %%
plt.figure(figsize=(8, 8))
plt.pie(entries_by_type, labels=entries_by_type.index, autopct='%1.1f%%', startangle=140)
plt.title('Type')
plt.axis('equal')
# Out:
# (-1.099999806153614,
#  1.099995938203087,
#  -1.0999927268955085,
#  1.0999996536330539)

# %%
state_type_counts = dataset.groupby(['state', 'type']).size().reset_index(name='count')
state_type_pivot = state_type_counts.pivot(index='state', columns='type', values='count').fillna(0)

# %%
state_type_pivot.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.xlabel('State')
plt.ylabel('Count')
plt.title('Number of Different Types in Each State')
plt.legend(title='Type', loc='upper right')
plt.show()

# %%
data = pd.read_csv('Dataset 2/RS_Session_256_AU_95_C.csv')
data
# Out:
#                                   State Name  Two Wheeler  Three Wheeler  \
# 0                 Andaman and Nicobar Island            1           30.0
# 1                          Arunachal Pradesh           14            NaN
# 2                                      Assam          721        47041.0
# 3                                      Bihar         5003        59079.0
# 4                                 Chandigarh          298         1410.0
# 5                               Chhattisgarh         6424         5341.0
# 6                                      Delhi        14730       112831.0
# 7                                        Goa         1314           28.0
# 8                                    Gujarat        13662         1869.0
# 9                                    Haryana         7777        18595.0
# 10                          Himachal Pradesh          368          167.0
# 11                         Jammu and Kashmir         1417           43.0
# 12                                 Jharkhand         2961         8986.0
# 13                                 Karnataka        56737        16478.0
# 14                                    Kerala        10299         2115.0
# 15                                    Ladakh           12            NaN
# 16                               Maharashtra        51149         6155.0
# 17                                   Manipur           86          443.0
# 18                                 Meghalaya           16            6.0
# 19                                   Mizoram            9            1.0
# 20                                  Nagaland           44            NaN
# 21                                    Odisha        10329         1808.0
# 22                                Puducherry         1429           32.0
# 23                                    Punjab         6408         2878.0
# 24                                 Rajasthan        23446        29631.0
# 25                                    Sikkim            1            NaN
# 26                                Tamil Nadu        44302         4470.0
# 27                                   Tripura           67         7510.0
# 28  Dadra and Nagar Haveli and Daman and Diu           69           36.0
# 29                             Uttar Pradesh        18295       257159.0
# 30                               Uttarakhand         2614        22096.0
# 31                               West Bengal         2540        40948.0
# 32                               Grand Total       282542       647186.0
#
#     Four Wheeler  Goods Vehicles  Public Service Vehicle  \
# 0             81             NaN                    40.0
# 1              5             NaN                     NaN
# 2            161             7.0                    15.0
# 3            114            11.0                    26.0
# 4            182             NaN                    40.0
# 5            117          1077.0                     1.0
# 6           3051            49.0                    39.0
# 7            289            13.0                    36.0
# 8           1309            28.0                   278.0
# 9            186           122.0                     8.0
# 10            37             7.0                    86.0
# 11            10             6.0                    43.0
# 12           139            24.0                     4.0
# 13          7212           153.0                    44.0
# 14          2524            43.0                    23.0
# 15          5484             NaN                     NaN
# 16             2            30.0                   851.0
# 17             9             1.0                     NaN
# 18             3             3.0                     NaN
# 19             4             2.0                     1.0
# 20           121             3.0                     NaN
# 21            75            21.0                     NaN
# 22           124             9.0                    20.0
# 23           798            35.0                     2.0
# 24            12            25.0                     1.0
# 25          2414             1.0                     NaN
# 26            13          1281.0                    37.0
# 27            14             1.0                     NaN
# 28           153             2.0                    10.0
# 29           368            53.0                   327.0
# 30           709             1.0                    10.0
# 31           615            28.0                    97.0
# 32         26335          3036.0                  2039.0
#
#     Special Category Vehicles  Ambulance/Hearses  \
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                         NaN                NaN
# 3                         NaN                NaN
# 4                         NaN                NaN
# 5                         NaN                NaN
# 6                         NaN                NaN
# 7                         2.0                NaN
# 8                       344.0                NaN
# 9                         2.0                NaN
# 10                        NaN                NaN
# 11                        NaN                NaN
# 12                        NaN                NaN
# 13                        1.0                1.0
# 14                        NaN                1.0
# 15                        NaN                NaN
# 16                       26.0                1.0
# 17                        NaN                NaN
# 18                        NaN                NaN
# 19                        NaN                NaN
# 20                        1.0                NaN
# 21                       25.0                NaN
# 22                        NaN                NaN
# 23                        NaN                NaN
# 24                        NaN                1.0
# 25                        NaN                NaN
# 26                        NaN                NaN
# 27                        NaN                NaN
# 28                        7.0                NaN
# 29                        2.0                NaN
# 30                        NaN                NaN
# 31                        NaN                2.0
# 32                      410.0                6.0
#
#     Construction Equipment Vehicle   Other  Grand Total
# 0                              NaN     7.0          159
# 1                              NaN     1.0           20
# 2                              NaN     2.0        47947
# 3                              NaN     8.0        64241
# 4                              NaN     1.0         1931
# 5                            368.0   100.0        13428
# 6                              NaN  1602.0       132302
# 7                              NaN     4.0         1686
# 8                             26.0    77.0        17593
# 9                              NaN    90.0        26780
# 10                             NaN    46.0          711
# 11                             NaN     8.0         1527
# 12                             NaN    57.0        12171
# 13                             NaN  1420.0        82046
# 14                             NaN    17.0        15022
# 15                             NaN     NaN         5496
# 16                             NaN   601.0        58815
# 17                             NaN     1.0          540
# 18                             NaN     NaN           28
# 19                             NaN     3.0           20
# 20                             1.0     1.0          171
# 21                             1.0    23.0        12282
# 22                             NaN     NaN         1614
# 23                             NaN    21.0        10142
# 24                             1.0    24.0        53141
# 25                             NaN     9.0         2425
# 26                             NaN   193.0        50296
# 27                             NaN     1.0         7593
# 28                             NaN     NaN          277
# 29                             NaN    13.0       276217
# 30                             NaN    21.0        25451
# 31                             NaN    61.0        44291
# 32                           397.0  4412.0       966363

# %%
data = data.drop(columns=["Ambulance/Hearses", "Construction Equipment Vehicle","Special Category Vehicles","Public Service Vehicle"])
data = data[data['State Name'] != 'Grand Total']

# %%
data.isnull().sum() / data.shape[0] * 100.00
# Out:
# State Name         0.0
# Two Wheeler        0.0
# Three Wheeler     12.5
# Four Wheeler       0.0
# Goods Vehicles    12.5
# Other             12.5
# Grand Total        0.0
# dtype: float64

# %%
data_filled_zero = data.fillna(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State Name      32 non-null     object
#  1   Two Wheeler     32 non-null     int64
#  2   Three Wheeler   28 non-null     float64
#  3   Four Wheeler    32 non-null     int64
#  4   Goods Vehicles  28 non-null     float64
#  5   Other           28 non-null     float64
#  6   Grand Total     32 non-null     int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 2.0+ KB

# %%
data = data.dropna(subset=['State Name'])

# Step 3: Fill missing values with zero
data.fillna(0, inplace=True)

# Step 4: Create pie charts for every state
states = data['State Name'].unique()

for state in states:
    state_data = data[data['State Name'] == state]
    
    # Set up the pie chart
    labels = ['Two Wheeler', 'Three Wheeler', 'Four Wheeler', 'Goods Vehicles', 'Other']
    sizes = state_data[['Two Wheeler', 'Three Wheeler', 'Four Wheeler', 'Goods Vehicles', 'Other']].iloc[0]
    colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen']
    explode = (0.1, 0, 0, 0, 0)  # explode the first slice
    
    # Plot the pie chart
    plt.figure(figsize=(8, 6))
    plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.title(f'Pie Chart for {state}')
    plt.show()

# %%
categories = ['Two Wheeler', 'Three Wheeler', 'Four Wheeler', 'Goods Vehicles', 'Other']

for category in categories:
    # Set up the bar graph
    plt.figure(figsize=(10, 6))
    sns.barplot(data=data, x='State Name', y=category, ci='sd')  # ci='sd' for showing median line (standard deviation)
    plt.xticks(rotation=90)
    plt.xlabel('State')
    plt.ylabel(f'{category}')
    plt.title(f'Bar Graph for {category}')
    plt.show()

# %%
correlation_matrix = dataset.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
